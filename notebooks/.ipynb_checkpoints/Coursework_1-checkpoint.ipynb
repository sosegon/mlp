# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def write_to_log_file(log_file_name, keys, stats):
    with open(log_file_name, "w+") as log_file:
        head = ""
        for k in keys:
            head = head + k + ","
        
        head = head[:-1]
        head = head + "\n"
        log_file.write(head)
        
        for log in stats:
            new_line = ""
            for value in log:
                new_line = new_line + "{:.8f},".format(value)                
            new_line = new_line[:-1]
            new_line = new_line + "\n"
            log_file.write(new_line)
    
    log_file.close()
    
def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)    
    
    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider

# Seed a random number generator
seed = 10102016 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=batch_size, rng=rng)

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser
from time import time

def activation_network(train_data, valid_data, rng, hyper, activation1, activation2, log_file_name):
    #setup hyperparameters
    batch_size = hyper[0]  # number of data points in a batch
    learning_rate = hyper[1]
    num_epochs = hyper[2]

    stats_interval = 1
    input_dim, output_dim, hidden_dim = 784, 10, 100

    # Reset random number generator and data provider states on each run
    # to ensure reproducibility of results
    rng.seed(seed)
    train_data.reset()
    valid_data.reset()

    # Alter data-provider batch size
    train_data.batch_size = batch_size 
    valid_data.batch_size = batch_size

    weights_init = GlorotUniformInit(rng=rng)
    biases_init = ConstantInit(0.)

    model = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
        activation1,
        AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
        activation2,
        AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
    ])

    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

    start = time()
    #Remember to use notebook=False when you write a script to be run in a terminal
    _ = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
    end = time()
    print("Total training time: {:.2f}s".format(end - start))

    write_to_log_file(log_file_name, _[1], _[0])

# %% [markdown]
# ## Different Activations [Low learning rate]

# %% [markdown]
# ### Sigmoid | Learning rate 0.05 | GlorotUniformInit

# %%
activation_network(train_data, valid_data, rng, [100, 0.05, 100], ReluLayer(), ReluLayer(), "sig_0_05_guniinit.txt")

# %% [markdown]
# ### ReLU | Learning rate 0.05 | GlorotUniformInit

# %%
activation_network(train_data, valid_data, rng, [100, 0.05, 100], ReluLayer(), ReluLayer(), "relu_0_05_guniinit.txt")

# %% [markdown]
# ### Leaky ReLU | Learning rate 0.05 | GlorotUniformInit

# %%
activation_network(train_data, valid_data, rng, [100, 0.05, 100], LeakyReluLayer(), LeakyReluLayer(), "lrelu_0_05_guniinit.txt")

# %% [markdown]
# ### ELU | Learning rate 0.05 | GlorotUniformInit

# %%
activation_network(train_data, valid_data, rng, [100, 0.05, 100], ELULayer(), ELULayer(), "elu_0_05_guniinit.txt")

# %% [markdown]
# ### SELU | Learning rate 0.05 | GlorotUniformInit

# %%
activation_network(train_data, valid_data, rng, [100, 0.05, 100], SELULayer(), SELULayer(), "selu_0_05_guniinit.txt")

# %% [markdown]
# ## Different Activations [High learning rate]

# %% [markdown]
# ### Sigmoid | Learning rate 0.5 | GlorotUniformInit

# %%
activation_network(train_data, valid_data, rng, [100, 0.5, 100], ReluLayer(), ReluLayer(), "sig_0_5_guniinit.txt")

# %% [markdown]
# ### ReLU | Learning rate 0.5 | GlorotUniformInit

# %%
activation_network(train_data, valid_data, rng, [100, 0.5, 100], ReluLayer(), ReluLayer(), "relu_0_5_guniinit.txt")

# %% [markdown]
# ### Leaky ReLU | Learning rate 0.5 | GlorotUniformInit

# %%
activation_network(train_data, valid_data, rng, [100, 0.5, 100], LeakyReluLayer(), LeakyReluLayer(), "lrelu_0_5_guniinit.txt")

# %% [markdown]
# ### ELU | Learning rate 0.5 | GlorotUniformInit

# %%
activation_network(train_data, valid_data, rng, [100, 0.5, 100], ELULayer(), ELULayer(), "elu_0_5_guniinit.txt")

# %% [markdown]
# ### SELU | Learning rate 0.5 | GlorotUniformInit

# %%
activation_network(train_data, valid_data, rng, [100, 0.5, 100], SELULayer(), SELULayer(), "selu_0_5_guniinit.txt")

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
# %matplotlib inline

def plot_results_for_comparisons():
    log_file_prefix = ["sig", "relu", "lrelu", "elu", "selu"]
    log_file_varian = ["_0_05_guniinit.txt", "_0_5_guniinit.txt"]
    hyper_settings = ["Learning rate: 0.05 | GlorotUniformInit", 
                      "Learning rate: 0.5 | GlorotUniformInit"]

    # train err | train acc | val err | val acc | params
    metrics_name = ["train ERR", "train ACC ", "val ERR", "val ACC", "params"]


    for varian, hyper in zip(log_file_varian, hyper_settings):
        metrics_list = [OrderedDict(), OrderedDict(), OrderedDict(), OrderedDict(), OrderedDict()]
        for net in log_file_prefix:
            file_name = net + varian
            net_metrics = np.loadtxt(file_name, delimiter=',', skiprows=1)
            assert len(metrics_list) == net_metrics.shape[1]
            for idx, ml in enumerate(metrics_list):
                ml[net] = net_metrics[:, idx]            

        f, ax = plt.subplots(len(metrics_list) - 1, 1, figsize=(20, 70))

        for ml, a, name in zip(metrics_list, ax, metrics_name):
            if name is "params":
                break
            for net in ml:
                a.plot(np.arange(1, len(ml[net])), ml[net][1:], label=net)
            a.legend(loc=0)
            a.set_title(name + " | " + hyper)
            a.set_xlabel("Epoch number")
            a.grid()

plot_results_for_comparisons()

# %% [markdown]
# # Compare networks of 2 - 8 layers with ELU

# %%
from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotNormalInit, SELUInit, NormalInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

def network(train_data, valid_data, rng, hyper, number_hidden_layers):
    seed = 10102016
    #setup hyperparameters
    batch_size = hyper[0]  # number of data points in a batch
    learning_rate = hyper[1]
    num_epochs = hyper[2]
    stats_interval = 1
    input_dim, output_dim, hidden_dim = 784, 10, 100

    # Reset random number generator and data provider states on each run
    # to ensure reproducibility of results
    rng.seed(seed)
    train_data.reset()
    valid_data.reset()

    # Alter data-provider batch size
    train_data.batch_size = batch_size 
    valid_data.batch_size = batch_size
    
    weights_init = NormalInit(0.1, 0.5, rng)
    biases_init = ConstantInit(0.)
        
    layers = []
    for i in range(1, number_hidden_layers + 1):
        
        if i == 1:
            layers.append(AffineLayer(input_dim, hidden_dim, weights_init, biases_init))
            layers.append(LeakyReluLayer())            
        elif i > 1 and i < number_hidden_layers:
            layers.append(AffineLayer(hidden_dim, hidden_dim))
            layers.append(LeakyReluLayer())
        else:
            layers.append(AffineLayer(hidden_dim, output_dim))

    model = MultipleLayerModel(layers)

    error = CrossEntropySoftmaxError()
    # Use a basic gradient descent learning rule
    learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

    start = time()
    #Remember to use notebook=False when you write a script to be run in a terminal
    _ = train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
    end = time()
    print("Total training time: {:.2f}s".format(end - start))

    write_to_log_file("elu_0_05_norminit_{:d}_layers.txt".format(number_hidden_layers), _[1], _[0])

# %%
network(train_data, valid_data, rng, [100, 0.05, 50], 2)
# Out:
# ...
# Epoch 1: 1.6s to complete
#     error(train)=5.50e-01, acc(train)=8.74e-01, error(valid)=5.22e-01, acc(valid)=8.79e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 1.6s to complete
#     error(train)=4.42e-01, acc(train)=8.89e-01, error(valid)=4.24e-01, acc(valid)=8.92e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 1.4s to complete
#     error(train)=3.87e-01, acc(train)=8.95e-01, error(valid)=3.85e-01, acc(valid)=8.98e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 1.4s to complete
#     error(train)=3.60e-01, acc(train)=8.97e-01, error(valid)=3.55e-01, acc(valid)=9.01e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 1.4s to complete
#     error(train)=3.25e-01, acc(train)=9.10e-01, error(valid)=3.23e-01, acc(valid)=9.12e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 1.5s to complete
#     error(train)=3.44e-01, acc(train)=9.03e-01, error(valid)=3.39e-01, acc(valid)=9.06e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 1.4s to complete
# ...

# %%
network(train_data, valid_data, rng, [100, 0.05, 50], 3)
# Out:
# ...
# Epoch 1: 2.0s to complete
#     error(train)=1.66e+00, acc(train)=5.29e-01, error(valid)=1.64e+00, acc(valid)=5.39e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 2.0s to complete
#     error(train)=1.26e+00, acc(train)=6.57e-01, error(valid)=1.23e+00, acc(valid)=6.76e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 1.8s to complete
#     error(train)=8.21e-01, acc(train)=7.81e-01, error(valid)=7.80e-01, acc(valid)=8.00e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 1.8s to complete
#     error(train)=6.04e-01, acc(train)=8.10e-01, error(valid)=5.63e-01, acc(valid)=8.25e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 2.1s to complete
#     error(train)=4.69e-01, acc(train)=8.63e-01, error(valid)=4.30e-01, acc(valid)=8.78e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 1.6s to complete
#     error(train)=4.27e-01, acc(train)=8.72e-01, error(valid)=3.93e-01, acc(valid)=8.80e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 2.0s to complete
# ...

# %%
network(train_data, valid_data, rng, [100, 0.05, 50], 4)
# Out:
# ...
# Epoch 1: 2.6s to complete
#     error(train)=1.08e+00, acc(train)=6.33e-01, error(valid)=1.01e+00, acc(valid)=6.56e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 2.6s to complete
#     error(train)=5.67e-01, acc(train)=8.13e-01, error(valid)=5.33e-01, acc(valid)=8.22e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 3.0s to complete
#     error(train)=3.34e-01, acc(train)=8.95e-01, error(valid)=3.12e-01, acc(valid)=9.02e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 2.3s to complete
#     error(train)=4.70e-01, acc(train)=8.49e-01, error(valid)=4.40e-01, acc(valid)=8.54e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 3.4s to complete
#     error(train)=2.52e-01, acc(train)=9.21e-01, error(valid)=2.41e-01, acc(valid)=9.25e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 2.8s to complete
#     error(train)=2.35e-01, acc(train)=9.25e-01, error(valid)=2.33e-01, acc(valid)=9.26e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 2.7s to complete
# ...

# %%
network(train_data, valid_data, rng, [100, 0.05, 50], 5)
# Out:
# ...
# Epoch 1: 2.8s to complete
#     error(train)=4.45e-01, acc(train)=8.66e-01, error(valid)=4.07e-01, acc(valid)=8.76e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 2.6s to complete
#     error(train)=3.25e-01, acc(train)=8.99e-01, error(valid)=3.00e-01, acc(valid)=9.04e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 2.8s to complete
#     error(train)=2.46e-01, acc(train)=9.23e-01, error(valid)=2.33e-01, acc(valid)=9.28e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 2.7s to complete
#     error(train)=3.39e-01, acc(train)=8.84e-01, error(valid)=3.20e-01, acc(valid)=8.87e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 2.6s to complete
#     error(train)=1.82e-01, acc(train)=9.43e-01, error(valid)=1.83e-01, acc(valid)=9.43e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 2.9s to complete
#     error(train)=1.59e-01, acc(train)=9.49e-01, error(valid)=1.66e-01, acc(valid)=9.48e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 2.8s to complete
# ...

# %%
network(train_data, valid_data, rng, [100, 0.05, 50], 6)
# Out:
# ...
# Epoch 1: 3.4s to complete
#     error(train)=8.30e-01, acc(train)=7.15e-01, error(valid)=7.86e-01, acc(valid)=7.32e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 3.6s to complete
#     error(train)=3.64e-01, acc(train)=8.88e-01, error(valid)=3.44e-01, acc(valid)=8.94e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 3.3s to complete
#     error(train)=2.69e-01, acc(train)=9.16e-01, error(valid)=2.54e-01, acc(valid)=9.19e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 3.2s to complete
#     error(train)=2.68e-01, acc(train)=9.12e-01, error(valid)=2.63e-01, acc(valid)=9.14e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 3.4s to complete
#     error(train)=2.21e-01, acc(train)=9.30e-01, error(valid)=2.18e-01, acc(valid)=9.31e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 3.3s to complete
#     error(train)=1.82e-01, acc(train)=9.42e-01, error(valid)=1.89e-01, acc(valid)=9.42e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 3.0s to complete
# ...

# %%
network(train_data, valid_data, rng, [100, 0.05, 50], 7)
# Out:
# ...
# Epoch 1: 3.7s to complete
#     error(train)=8.75e-01, acc(train)=7.04e-01, error(valid)=8.34e-01, acc(valid)=7.21e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 4.1s to complete
#     error(train)=5.41e-01, acc(train)=8.20e-01, error(valid)=5.13e-01, acc(valid)=8.30e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 5.0s to complete
#     error(train)=2.95e-01, acc(train)=9.08e-01, error(valid)=2.75e-01, acc(valid)=9.12e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 4.4s to complete
#     error(train)=3.86e-01, acc(train)=8.71e-01, error(valid)=3.63e-01, acc(valid)=8.79e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 3.9s to complete
#     error(train)=2.24e-01, acc(train)=9.28e-01, error(valid)=2.15e-01, acc(valid)=9.33e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 3.8s to complete
#     error(train)=1.81e-01, acc(train)=9.43e-01, error(valid)=1.85e-01, acc(valid)=9.43e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 3.6s to complete
# ...

# %%
network(train_data, valid_data, rng, [100, 0.05, 50], 8)
# Out:
# ...
# Epoch 1: 4.0s to complete
#     error(train)=1.08e+00, acc(train)=6.14e-01, error(valid)=1.05e+00, acc(valid)=6.36e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 4.4s to complete
#     error(train)=5.58e-01, acc(train)=8.26e-01, error(valid)=5.30e-01, acc(valid)=8.34e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 4.4s to complete
#     error(train)=3.20e-01, acc(train)=9.01e-01, error(valid)=2.99e-01, acc(valid)=9.05e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 4.2s to complete
#     error(train)=8.52e-01, acc(train)=8.15e-01, error(valid)=8.10e-01, acc(valid)=8.19e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 4.4s to complete
#     error(train)=2.62e-01, acc(train)=9.17e-01, error(valid)=2.45e-01, acc(valid)=9.23e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 4.2s to complete
#     error(train)=2.18e-01, acc(train)=9.31e-01, error(valid)=2.12e-01, acc(valid)=9.33e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 4.5s to complete
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
# %matplotlib inline

def plot_results_for_comparisons_mult():
    number_layers = range(2, 9)
    metrics_name = ["train ERR", "train ACC ", "val ERR", "val ACC", "params"]
    hyper = "Learning rate: 0.05 | NormalInit | Leaky Relu"

    metrics_list = [OrderedDict(), OrderedDict(), OrderedDict(), OrderedDict(), OrderedDict()]
    for net in number_layers:                
        file_name = "elu_0_05_norminit_{:d}_layers.txt".format(net)
        net_metrics = np.loadtxt(file_name, delimiter=',', skiprows=1)
        assert len(metrics_list) == net_metrics.shape[1]
        for idx, ml in enumerate(metrics_list):
            ml[net] = net_metrics[:, idx]            

    f, ax = plt.subplots(len(metrics_list) - 1, 1, figsize=(20, 70))

    for ml, a, name in zip(metrics_list, ax, metrics_name):
        if name is "params":
            break
        for net in ml:
            a.plot(np.arange(1, len(ml[net])), ml[net][1:], label="layers: {:d}".format(net))
        a.legend(loc=0)
        a.set_title(name + " | " + hyper)
        a.set_xlabel("Epoch number")
        a.grid()

plot_results_for_comparisons_mult()
